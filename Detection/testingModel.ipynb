# %% [markdown]
# # Testando o modelo

# %% [markdown]
# O modelo foi treinado e obteve os seguintes resultados:
# Desempenho Geral (all):
#     Precisão de 87.7%
#     O recall de 84.7%
#     O mAP@50 de 91.3%
#     O mAP@50-95 de 77.9%

# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import torch
from PIL import Image
import matplotlib.pyplot as plt
import cv2

model = YOLO('yolo11n.pt')

# %%
def classify_image(image_path):    
    results = model(image_path)
    
    # Display results
    for result in results:
        img_rgb = cv2.cvtColor(result.plot(show=False), cv2.COLOR_BGR2RGB)
        plt.figure(figsize=(10, 10))
        plt.imshow(img_rgb)
        plt.axis('off')
        plt.show()
    
    # Optionally, print the results
    # print(results)

# %%
image_path = r'imagensExemplo\yorkShire.jpg'
classify_image(image_path)
# Out:
# image 1/1 c:\Users\luis\Documents\pessoal\yoloProject\imagensExemplo\yorkShire.jpg: 576x640 1 Yorkshire_terrier, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 576, 640)

# %%
image_path = r'imagensExemplo\yorkShire2.jpg'
classify_image(image_path)
# Out:
# image 1/1 c:\Users\luis\Documents\pessoal\yoloProject\imagensExemplo\yorkShire2.jpg: 640x480 1 Yorkshire_terrier, 32.0ms
# Speed: 5.0ms preprocess, 32.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
image_path = r'imagensExemplo\shitTzu.jpg'
classify_image(image_path)
# Out:
# image 1/1 c:\Users\luis\Documents\pessoal\yoloProject\imagensExemplo\shitTzu.jpg: 640x384 1 Shih-Tzu, 90.7ms
# Speed: 3.0ms preprocess, 90.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)

# %%
image_path = r'imagensExemplo/boxer.jpg'
classify_image(image_path)
# Out:
# image 1/1 c:\Users\luis\Documents\pessoal\yoloProject\imagensExemplo\boxer.jpg: 448x640 1 boxer, 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
image_path = r'imagensExemplo/shitTzu2.jpg'
classify_image(image_path)
# Out:
# image 1/1 c:\Users\luis\Documents\pessoal\yoloProject\imagensExemplo\shitTzu2.jpg: 640x480 1 Shih-Tzu, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 107.0ms postprocess per image at shape (1, 3, 640, 480)
